# %%
import cv2
from face_recog_lib import *
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
known_encodings, known_names = get_known_encodings('faces')
known_names
# Out:
# Extracting face encodings from Mikhail.jpg
# Extracting face encodings from daun.jpg
# Extracting face encodings from Timofey.jpg
# ['Mikhail', 'daun', 'Timofey']

# %%
image = cv2.imread('celebs/fassbender/fassbender1.jpg')
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
for i in range(5):
    boxes = get_boxes(image)
    boxes = get_boxes(image)
    print(len(boxes))
    print(boxes)

    faces = get_faces(image)

    print('Extracting faces')

    encodings = get_embedding_list(faces)

    print('Extracting embeddings')

    names = compare_faces(encodings, known_encodings, known_names)
    print(len(names))

    print('Getting names')

    boxes_and_names(image, boxes, names)

    print('Drawing boxes')
# Out:
# 1
# [(134, 206, 455, 527)]
# Extracting faces
# Extracting embeddings
# [136.4857, 134.69351, 199.55269, 125.63739, 165.74655, 132.28769, 114.27332, 156.93002, 131.44627, 100.15622, 104.33346, 182.61975, 130.91583, 101.235405, 130.03134, 167.38179, 125.73751, 144.73737, 84.57129, 135.16943]
# Min dist: 84.57129
# 1
# Getting names
# Drawing boxes
# 1
# [(171, 260, 438, 528)]
# Extracting faces
# Extracting embeddings
# [59.85352, 46.54985, 144.44067, 37.932243, 98.921906, 49.16466, 50.081055, 71.28597, 56.248333, 34.47255, 59.070274, 85.787636, 70.54036, 49.24611, 57.984394, 130.09319, 75.48682, 49.704826, 68.40124, 75.21684]
# Min dist: 34.47255
# 1
# Getting names
# Drawing boxes
# 1
# [(171, 260, 438, 528)]
# Extracting faces
# Extracting embeddings
# [57.866295, 43.77745, 145.33105, 35.211777, 93.78709, 48.06666, 49.54251, 65.103195, 55.460712, 32.674896, 59.09265, 83.55799, 64.51078, 46.387688, 55.87415, 129.73718, 75.55014, 46.985023, 66.22574, 72.50517]
# Min dist: 32.674896
# 1
# Getting names
# Drawing boxes
# 1
# [(171, 260, 438, 528)]
# Extracting faces
# Extracting embeddings
# [57.866295, 43.77745, 145.33105, 35.211777, 93.78709, 48.06666, 49.54251, 65.103195, 55.460712, 32.674896, 59.09265, 83.55799, 64.51078, 46.387688, 55.87415, 129.73718, 75.55014, 46.985023, 66.22574, 72.50517]
# Min dist: 32.674896
# 1
# Getting names
# Drawing boxes
# 1
# [(171, 260, 438, 528)]
# Extracting faces
# Extracting embeddings
# [57.866295, 43.77745, 145.33105, 35.211777, 93.78709, 48.06666, 49.54251, 65.103195, 55.460712, 32.674896, 59.09265, 83.55799, 64.51078, 46.387688, 55.87415, 129.73718, 75.55014, 46.985023, 66.22574, 72.50517]
# Min dist: 32.674896
# 1
# Getting names
# Drawing boxes

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
imgplot = plt.imshow(image)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cv2.imwrite('outo_test.png', image)
# Out:
# True

# %%
def get_name(image):
    for i in range(5):
        boxes = get_boxes(image)
        #print(len(boxes))

        faces = get_faces(image)

        #print('Extracting faces')

        encodings = get_embedding_list(faces)
        print(encodings)
        

        #print('Extracting embeddings')

        names = compare_faces(encodings, known_encodings, known_names)
        print(names)
        name = names[0]
    return name
        
image_ = cv2.imread('faces/daun.jpg')
get_name(image_)
# Out:
# [[ 2.8716263e-01  9.6844959e-01  2.4235919e-01 -3.0430934e-01
#   -1.5822750e-01 -2.9676539e-01  3.8399293e+00  7.3649222e-01
#    1.9369093e-01  1.0360489e+00 -4.0454775e-01  9.8975375e-04
#   -1.3795444e-01  7.6067604e-02 -9.8350352e-01 -2.3185827e-01
#    1.1067945e+00 -1.2951890e-01  1.2147001e+00  9.3032122e-02
#    3.5212643e+00  7.7064854e-01 -1.6086586e+00 -1.7895689e+00
#   -3.7475690e-01  1.3828903e+00  7.1154749e-01 -6.0522866e-01
#    1.7949910e-01  2.3302255e+00  5.4180014e-01 -1.0056946e+00
#    1.5394200e-02  2.3556097e+00 -1.6120036e+00 -1.6675787e-01
#    1.1732008e+00 -1.5329987e+00 -5.8407700e-01  5.5856979e-01
#    2.7226919e-01 -1.1006763e+00 -4.9216299e+00  5.5797994e-01
#    4.4752097e-01 -1.3790270e+00  4.6642458e-01  4.5354411e-01
#   -3.9394948e-01  1.4767034e+00 -1.1253332e+00 -3.4284517e-01
#    1.4746324e+00 -3.0959523e-01  6.6228008e-01 -1.1039614e-01
#    9.0286797e-01 -1.6811823e+00 -1.3977486e+00  4.7159204e-01
#    2.6354620e-01 -5.1970309e-01  4.1078621e-01 -6.4335871e-01
#    8.1839406e-01  2.7827382e+00  7.6647103e-01  1.2421058e+00
#    5.5940312e-01  4.5035309e-01  9.1027421e-01 -8.5632965e-02
#    1.1736183e+00  4.6990314e-01 -9.4708627e-01  1.7197002e-01
#    5.2096760e-01  3.9376140e-01 -1.0455400e-01  5.4894751e-01
#   -7.8866428e-01 -1.5279034e+00  2.6325515e-01  1.8385795e-01
#    2.1778148e-01 -1.5850518e+00  5.9858429e-01  1.7410165e-01
#    1.7354172e+00  6.7547238e-01  4.3995535e-01 -9.9487774e-02
#    6.5304142e-01  1.1812840e+00  4.2575550e-01  3.3575916e-01
#    1.9753166e-03  3.2367381e-01 -7.1699500e-01  9.0470952e-01
#    1.1411806e-01  9.4787562e-01 -1.2588199e-02  1.3990610e+00
#    1.1615872e+00  6.6231143e-01  6.4737087e-01  1.1486942e+00
#   -8.0063891e-01 -4.9175334e-01 -5.1939213e-01 -1.0116326e-01
#    1.3022567e-04 -2.9918289e-01 -5.8019905e+00  4.9264073e-02
#    1.3072493e+00 -1.2444910e+00  1.4861234e-01 -3.5187015e-01
#   -2.4879915e-01  6.2167019e-02  3.3802211e-01 -9.8049664e-01
#    3.2305145e-01 -1.3294486e+00 -1.1407090e+00 -4.7938985e-01]]
#    1.5394200e-02  2.3556097e+00 -1.6120036e+00 -1.6675787e-01
#    1.1732008e+00 -1.5329987e+00 -5.8407700e-01  5.5856979e-01
#    2.7226919e-01 -1.1006763e+00 -4.9216299e+00  5.5797994e-01
#    4.4752097e-01 -1.3790270e+00  4.6642458e-01  4.5354411e-01
#   -3.9394948e-01  1.4767034e+00 -1.1253332e+00 -3.4284517e-01
#    1.4746324e+00 -3.0959523e-01  6.6228008e-01 -1.1039614e-01
#    9.0286797e-01 -1.6811823e+00 -1.3977486e+00  4.7159204e-01
#    2.6354620e-01 -5.1970309e-01  4.1078621e-01 -6.4335871e-01
#    8.1839406e-01  2.7827382e+00  7.6647103e-01  1.2421058e+00
#    5.5940312e-01  4.5035309e-01  9.1027421e-01 -8.5632965e-02
#    1.1736183e+00  4.6990314e-01 -9.4708627e-01  1.7197002e-01
#    5.2096760e-01  3.9376140e-01 -1.0455400e-01  5.4894751e-01
#   -7.8866428e-01 -1.5279034e+00  2.6325515e-01  1.8385795e-01
#    2.1778148e-01 -1.5850518e+00  5.9858429e-01  1.7410165e-01
#    1.7354172e+00  6.7547238e-01  4.3995535e-01 -9.9487774e-02
#    6.5304142e-01  1.1812840e+00  4.2575550e-01  3.3575916e-01
#    1.9753166e-03  3.2367381e-01 -7.1699500e-01  9.0470952e-01
#    1.1411806e-01  9.4787562e-01 -1.2588199e-02  1.3990610e+00
#    1.1615872e+00  6.6231143e-01  6.4737087e-01  1.1486942e+00
#   -8.0063891e-01 -4.9175334e-01 -5.1939213e-01 -1.0116326e-01
#    1.3022567e-04 -2.9918289e-01 -5.8019905e+00  4.9264073e-02
#    1.3072493e+00 -1.2444910e+00  1.4861234e-01 -3.5187015e-01
#   -2.4879915e-01  6.2167019e-02  3.3802211e-01 -9.8049664e-01
#    3.2305145e-01 -1.3294486e+00 -1.1407090e+00 -4.7938985e-01]]
# [63.12365, 0.0, 59.167397]
# Min dist: 0.0
# ['Mikhail']
# 'Mikhail'

# %%
import numpy as np

image_ = cv2.imread('celebs/smith/smith1.jpg')
for i in range(5):
    boxes = get_boxes(image_)
    print(len(boxes))

    faces = get_faces(image_)

    print('Extracting faces')

    encodings = get_embedding_list(faces)
    encoding = encodings[0]

for i in range(len(known_names)):
    print(known_names[i], end = " ")
    print(np.sum(np.square(encodings[0] - known_encodings[i])))
# Out:
# 1
# Extracting faces
# 1
# Extracting faces
# 1
# Extracting faces
# 1
# Extracting faces
# 1
# Extracting faces
# lawrence 145.03581
# rihanna 97.668335
# hanks 86.642365
# clooney 124.95154
# jolie 123.238945
# downey 123.22162
# chan 114.800095
# dicaprio 85.98007
# cruise 99.24344
# beyonce 89.773895
# swift 121.28682
# johansson 149.06734
# cumberbatch 106.76183
# watson 169.27075
# smith 66.437584
# fox 156.19089
# pitt 107.664246
# alba 129.04446
# aniston 106.83739
