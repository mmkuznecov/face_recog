# %%
import dlib
from skimage import io
from scipy.spatial import distance
import cv2

# %%
pred = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')
facerec = dlib.face_recognition_model_v1('dlib_face_recognition_resnet_model_v1.dat')
detector = dlib.get_frontal_face_detector()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-7d3b6b5a1767> in <module>
# ----> 1 pred = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')
#       2 facerec = dlib.face_recognition_model_v1('dlib_face_recognition_resnet_model_v1.dat')
#       3 detector = dlib.get_frontal_face_detector()
#
# RuntimeError: Unable to open shape_predictor_68_face_landmarks.dat

# %%
cv = cv2.imread('Mikhail.jpg')
sk = io.imread('Mikhail.jpg')
cv = cv2.imread('Mikhail.jpg')
cv = cv2.cvtColor(sk, cv2.COLOR_BGR2RGB)
print(len(sk))
print('===========')
print(len(cv))
# Out:
# 1080
# ===========
# 1080

# %%
w = dlib.image_window()
w.clear_overlay()
w.set_image(sk)

# %%
dets = detector(cv, 1)
dets
# Out:
# rectangles[[(170, 420) (491, 741)]]

# %%
for k, d in enumerate(dets):
    print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
        k, d.left(), d.top(), d.right(), d.bottom()))
    shape = pred(sk, d)
    w.clear_overlay()
    w.add_overlay(d)
    w.add_overlay(shape)
# Out:
# Detection 0: Left: 170 Top: 420 Right: 491 Bottom: 741

# %%
face_descriptor1 = facerec.compute_face_descriptor(sk, shape)
face_descriptor1
print(type(face_descriptor1))
print(len(face_descriptor1))
print(face_descriptor1)
# Out:
# <class 'dlib.vector'>
# 128
# -0.174802
# 0.0502696
# 0.0511258
# -0.0501205
# -0.0954701
# 0.0649128
# -0.0265777
# -0.121462
# 0.202631
# -0.181211
# 0.208547
# -0.0263282
# -0.202447
# -0.059472
# 0.0186464
# 0.174684
# -0.0962769
# -0.0956618
# -0.102379
# -0.0186323
# 0.0236079
# 0.00160116
# -0.0180076
# 0.0826108
# -0.180721
# -0.423192
# -0.125842
# -0.133816
# -0.0202344
# -0.0830069
# -0.037223
# 0.0232043
# -0.0899641
# 0.0193491
# -0.0336095
# 0.0810474
# -0.0415648
# -0.0474187
# 0.228129
# 0.00937739
# -0.208614
# -0.0059916
# -0.0170781
# 0.278032
# 0.167109
# -0.0170129
# 0.0865883
# -0.0346949
# 0.170047
# -0.233275
# 0.087295
# 0.0527285
# 0.129788
# 0.0532542
# 0.0740801
# -0.100804
# -0.0371736
# 0.155736
# -0.221087
# 0.104132
# 0.0419187
# -0.122088
# -0.0751747
# -0.0533176
# 0.241534
# 0.181105
# -0.161894
# -0.117972
# 0.217017
# -0.1495
# 0.00152963
# -0.000391941
# -0.160994
# -0.208754
# -0.309056
# 0.0452766
# 0.450728
# 0.155184
# -0.222287
# -0.0564172
# -0.115577
# -0.0307212
# 0.068357
# 0.105911
# 0.00691547
# -0.0871292
# -0.0182875
# 0.0378694
# 0.248733
# -0.00847691
# -0.0165434
# 0.246575
# 0.0423237
# 0.00771026
# -0.0420032
# 0.0198315
# -0.0755485
# -0.039281
# -0.0456119
# 0.0562708
# -0.0393797
# -0.066453
# 0.0335603
# 0.0856998
# -0.240294
# 0.285572
# 0.0365419
# 0.0178653
# 0.0437283
# 0.0630616
# -0.173833
# -0.0306796
# 0.203149
# -0.263989
# 0.140716
# 0.174086
# 0.0864278
# 0.170273
# 0.0195972
# 0.0645502
# 0.0163396
# 0.00648722
# -0.231985
# -0.0407267
# 0.0813937
# -0.0603489
# 0.0269813
# 0.0791591

# %%
img = io.imread('Timofey.jpg')
win2 = dlib.image_window()

win2.clear_overlay()
win2.set_image(img)
dets_webcam = detector(img, 1)
for k, d in enumerate(dets_webcam):
    print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
        k, d.left(), d.top(), d.right(), d.bottom()))
    shape = pred(img, d)
    win2.clear_overlay()
    win2.add_overlay(d)
    win2.add_overlay(shape)
# Out:
# Detection 0: Left: 139 Top: 254 Right: 268 Bottom: 383

# %%
face_descriptor2 = facerec.compute_face_descriptor(img, shape)

# %%
a = distance.euclidean(face_descriptor1, face_descriptor2)
print(a)
# Out:
# 0.757985364490802

# %%
print(distance.euclidean([1,3],[5,7]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e5cb621d54a0> in <module>
# ----> 1 print(distance.euclidean([1,3],[5,7]))
#
# NameError: name 'distance' is not defined

# %%
image = cv2.imread('/home/mikhail/Загрузки/bbt_large.jpg')

# %%
detector = dlib.get_frontal_face_detector()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
faceRects = detector(image, 0)
for faceRect in faceRects:
    x1 = faceRect.left()
    y1 = faceRect.top()
    x2 = faceRect.right()
    y2 = faceRect.bottom()
    cv2.rectangle(image, (x1, y1), (x2, y2), (255,0,0), 2)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
